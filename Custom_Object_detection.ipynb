# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-295-gac6c4383 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.9/78.2 GB disk)

# %%
# %cd /content/drive/MyDrive/model/yolov5

# %%
# !python train.py --img 640 --batch 3 --epochs 500 --data /content/drive/MyDrive/model/yolov5/data/custom_data.yaml --weights yolov5s.pt --cache
# Out:
# 2024-03-30 13:46:14.725868: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-30 13:46:14.725983: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-30 13:46:14.812125: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from google.colab import drive
from google.colab import files
import os

# Mount Google Drive
drive.mount('/content/drive')

# Function to select an image from Google Drive and run detection
def select_image_and_detect():
    # Provide an interface to select an image from Google Drive
    print("Please select an image from Google Drive:")
    uploaded = files.upload()

    # Get the path of the uploaded image
    file_name = list(uploaded.keys())[0]
    file_path = f"/content/{file_name}"

    # Run detection command with the selected image
    detection_command = f"!python detect.py --source '{file_path}' --weights /content/drive/MyDrive/model/yolov5/runs/train/exp9/weights/best.pt"
    os.system(detection_command)

# Call the function to select image and run detection
select_image_and_detect()

# %%
# !python detect.py --source "/content/drive/MyDrive/model/custom_data/testing" --weights /content/drive/MyDrive/model/yolov5/runs/train/exp9/weights/best.pt

# %%
# !yolo val model=/content/drive/MyDrive/model/yolov5/runs/train/exp/weights/best.pt data=/content/drive/MyDrive/custom_data.yaml split=test
